# %% [markdown]
# # Model Training Notebook
# Use this notebook for experimentation before production training in `src/train_model.py`.

# %%
from pathlib import Path
import pandas as pd

data_path = Path('../data/spam.csv')
df = pd.read_csv(data_path)
df.head()
